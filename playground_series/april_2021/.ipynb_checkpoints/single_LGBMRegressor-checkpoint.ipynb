# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # 数据可视化
# 读取数据

# %%
train_data_path = './data/train.csv'
test_data_path = './data/test.csv'

train_data = pd.read_csv(train_data_path)
test_data = pd.read_csv(test_data_path)

# %% [markdown]
# 查看数据基本情况

# %%
#SibSp：配偶或者兄弟姐妹；parch：父母或者孩子；fare：票价；cabin：舱号
train_data.head()
# Out:
#    PassengerId  Survived  Pclass              Name   Sex    Age  SibSp  Parch  \
# 0            0         1       1  Oconnor, Frankie  male    NaN      2      0
# 1            1         0       3       Bryan, Drew  male    NaN      0      0
# 2            2         0       3    Owens, Kenneth  male   0.33      1      2
# 3            3         0       3     Kramer, James  male  19.00      0      0
# 4            4         1       3     Bond, Michael  male  25.00      0      0
#
#       Ticket   Fare   Cabin Embarked
# 0     209245  27.14  C12239        S
# 1      27323  13.35     NaN        S
# 2  CA 457703  71.29     NaN        S
# 3   A. 10866  13.04     NaN        S
# 4     427635   7.76     NaN        S

# %%
test_data.head()
# Out:
#    PassengerId  Pclass              Name     Sex   Age  SibSp  Parch  Ticket  \
# 0       100000       3  Holliday, Daniel    male  19.0      0      0   24745
# 1       100001       3  Nguyen, Lorraine  female  53.0      0      0   13264
# 2       100002       1   Harris, Heather  female  19.0      0      0   25990
# 3       100003       2      Larsen, Eric    male  25.0      0      0  314011
# 4       100004       1     Cleary, Sarah  female  17.0      0      2   26203
#
#     Fare   Cabin Embarked
# 0  63.01     NaN        S
# 1   5.81     NaN        S
# 2  38.91  B15315        C
# 3  12.93     NaN        S
# 4  26.89  B22515        C

# %%
print(train_data.describe())
print(test_data.describe())
# Out:
#          PassengerId       Survived         Pclass           Age  \
# count  100000.000000  100000.000000  100000.000000  96708.000000
# mean    49999.500000       0.427740       2.106910     38.355472
# std     28867.657797       0.494753       0.837727     18.313556
# min         0.000000       0.000000       1.000000      0.080000
# 25%     24999.750000       0.000000       1.000000     25.000000
# 50%     49999.500000       0.000000       2.000000     39.000000
# 75%     74999.250000       1.000000       3.000000     53.000000
# max     99999.000000       1.000000       3.000000     87.000000
#
#                SibSp          Parch         Fare
# count  100000.000000  100000.000000  99866.00000
# mean        0.397690       0.454560     43.92933
# std         0.862566       0.950076     69.58882
# min         0.000000       0.000000      0.68000
# 25%         0.000000       0.000000     10.04000
# 50%         0.000000       0.000000     24.46000
# ...

# %%
#查看空值
print('------null值------')
print(train_data.isnull().sum())
print('------nan值------')
print(train_data.isna().sum())
# Out:
# ------null值------
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age             3292
# SibSp              0
# Parch              0
# Ticket          4623
# Fare             134
# Cabin          67866
# Embarked         250
# dtype: int64
# ------nan值------
# PassengerId        0
# Survived           0
# Pclass             0
# Name               0
# Sex                0
# Age             3292
# SibSp              0
# Parch              0
# Ticket          4623
# Fare             134
# Cabin          67866
# Embarked         250
# dtype: int64

# %%
print('------null值------')
print(test_data.isnull().sum())
print('------nan值------')
print(test_data.isna().sum())
# Out:
# ------null值------
# PassengerId        0
# Pclass             0
# Name               0
# Sex                0
# Age             3487
# SibSp              0
# Parch              0
# Ticket          5181
# Fare             133
# Cabin          70831
# Embarked         277
# dtype: int64
# ------nan值------
# PassengerId        0
# Pclass             0
# Name               0
# Sex                0
# Age             3487
# SibSp              0
# Parch              0
# Ticket          5181
# Fare             133
# Cabin          70831
# Embarked         277
# dtype: int64

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 12 columns):
# PassengerId    100000 non-null int64
# Survived       100000 non-null int64
# Pclass         100000 non-null int64
# Name           100000 non-null object
# Sex            100000 non-null object
# Age            96708 non-null float64
# SibSp          100000 non-null int64
# Parch          100000 non-null int64
# Ticket         95377 non-null object
# Fare           99866 non-null float64
# Cabin          32134 non-null object
# Embarked       99750 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 9.2+ MB

# %%
test_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 11 columns):
# PassengerId    100000 non-null int64
# Pclass         100000 non-null int64
# Name           100000 non-null object
# Sex            100000 non-null object
# Age            96513 non-null float64
# SibSp          100000 non-null int64
# Parch          100000 non-null int64
# Ticket         94819 non-null object
# Fare           99867 non-null float64
# Cabin          29169 non-null object
# Embarked       99723 non-null object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 8.4+ MB

# %% [markdown]
# 可视化分析

# %%
from pylab import mpl

mpl.rcParams['font.sans-serif'] = ['FangSong'] # 指定默认字体
'''
color list
'antiquewhite':         '#FAEBD7',
'aqua':                 '#00FFFF',
'aquamarine':           '#7FFFD4',
'azure':                '#F0FFFF',
'beige':                '#F5F5DC',
'bisque':               '#FFE4C4',
'black':                '#000000',
'blanchedalmond':       '#FFEBCD',
'blue':                 '#0000FF',
'blueviolet':           '#8A2BE2',
'brown':                '#A52A2A',
'burlywood':            '#DEB887',
'cadetblue':            '#5F9EA0',
'chartreuse':           '#7FFF00'
'''
'''
Survived       100000 non-null int64
Pclass         100000 non-null int64
Name           100000 non-null object
Sex            100000 non-null object
Age            96708 non-null float64
SibSp          100000 non-null int64
Parch          100000 non-null int64
Ticket         95377 non-null object
Fare           99866 non-null float64
Cabin          32134 non-null object
Embarked       99750 non-null object
'''

fig = plt.figure(figsize=(12, 8))
#可视化每个属性的分布情况
#Survived分布情况
plt.subplot2grid((3, 3), (0, 0), rowspan=1, colspan=1)
train_data['Survived'].value_counts(normalize=True).plot(kind='bar', color='#FAEBD7')
plt.title('生存情况,(0未生存,1生存)')
plt.xlabel('生存状态')
plt.ylabel('分布情况')

#Pclass分布情况
plt.subplot2grid((3, 3), (0, 1), rowspan=1, colspan=1)
train_data['Pclass'].value_counts(normalize=True).plot(kind='bar', color='#00FFFF')
plt.title('船票等级情况')
plt.xlabel('船票等级')
plt.ylabel('分布情况')

#性别分布情况
plt.subplot2grid((3, 3), (0, 2), rowspan=1, colspan=1)
train_data['Sex'].value_counts(normalize=True).plot(kind='bar', color='#7FFFD4')
plt.title('性别分布情况')
plt.xlabel('性别')
plt.ylabel('分布情况')

#年龄分布情况(可视化出错)
plt.subplot2grid((3, 3), (1, 0), rowspan=1, colspan=1)
#直方图直接plot,无需value_counts
train_data['Age'].plot(kind='hist', color='#F0FFFF')
plt.title('年龄分布情况')
plt.xlabel('年龄')
plt.ylabel('人数')

#Sibsp：兄弟姐妹或者配偶数
plt.subplot2grid((3, 3), (1, 1), rowspan=1, colspan=1)
train_data['SibSp'].value_counts(normalize=True).plot(kind='bar', color='#F5F5DC')
plt.title('SibSp分布情况')
plt.xlabel('人数')
plt.ylabel('分布情况')

#Parch：父母或者子女数
plt.subplot2grid((3, 3), (1, 2), rowspan=1, colspan=1)
train_data['Parch'].value_counts(normalize=True).plot(kind='bar', color='#FFE4C4')
plt.title('Parch分布情况')
plt.xlabel('人数')
plt.ylabel('分布情况')

#Fare：船票价格
plt.subplot2grid((3, 3), (2, 0), rowspan=1, colspan=1)
train_data['Fare'].plot(kind='hist', color='#0000FF')
plt.title('船票价格分布情况')
plt.xlabel('船票价格')
plt.ylabel('数量')

#Embarked：港口
plt.subplot2grid((3, 3), (2, 1), rowspan=1, colspan=2)
train_data['Embarked'].value_counts(normalize=True).plot(kind='bar', color='#8A2BE2')
plt.title('港口分布情况')
plt.xlabel('港口')
plt.ylabel('分布情况')

plt.tight_layout()

# %%
#可视化生存人数与各个属性之间的关系
#Pclass:船票等级
#最后一个语句添加分号可以去除掉提示性的文字
#1级和2级的乘客获救比例较大，3级乘客未获救比例较大
Survived_0 = train_data.Pclass[train_data.Survived == 0].value_counts()
Survived_1 = train_data.Pclass[train_data.Survived == 1].value_counts()
df = pd.DataFrame({'未获救' : Survived_0, '获救' : Survived_1})
df.plot(kind='bar')
plt.title('不同船票等级的生存情况')
plt.xlabel('船票')
plt.ylabel('人数');

# %%
#Sex:性别
#女性获救比例较大，男性获救比例较小
Survived_0 = train_data.Sex[train_data.Survived == 0].value_counts()
Survived_1 = train_data.Sex[train_data.Survived == 1].value_counts()
df = pd.DataFrame({'未获救' : Survived_0, '获救' : Survived_1})
df.plot(kind='bar')
plt.title('不同性别的生存情况')
plt.xlabel('性别')
plt.ylabel('人数');

# %%
#Sibsp：兄弟姐妹或者配偶数
#可以看出不管兄弟姐妹和配偶数，都是未获救的比例居多
Survived_0 = train_data.SibSp[train_data.Survived == 0].value_counts()
Survived_1 = train_data.SibSp[train_data.Survived == 1].value_counts()
df = pd.DataFrame({'未获救' : Survived_0, '获救' : Survived_1})
df.plot(kind='bar')
plt.title('Sibsp生存情况')
plt.xlabel('SibSp数量')
plt.ylabel('人数');

# %%
#Parch：父母或者子女数
#从图中看到只有Parch的值为1的时候获救的比例比较大，是单亲家庭或者独生子女占了好处？
Survived_0 = train_data.Parch[train_data.Survived == 0].value_counts()
Survived_1 = train_data.Parch[train_data.Survived == 1].value_counts()
df = pd.DataFrame({'未获救' : Survived_0, '获救' : Survived_1})
df.plot(kind='bar')
plt.title('Parch生存情况')
plt.xlabel('数量')
plt.ylabel('人数');

# %%
#Embarked：港口
#C和Q港口的获救人数比例较大，S港口获救人数比例小
Survived_0 = train_data.Embarked[train_data.Survived == 0].value_counts()
Survived_1 = train_data.Embarked[train_data.Survived == 1].value_counts()
df = pd.DataFrame({'未获救' : Survived_0, '获救' : Survived_1})
df.plot(kind='bar')
plt.title('不同港口的生存情况')
plt.xlabel('港口')
plt.ylabel('人数');

# %%
#训练和测试使用的数据均有10万例，均存在空值，对这些数据合并处理
data_all = pd.concat([train_data, test_data], axis=0)
# Out:
# D:\Anaconda\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False

# %% [markdown]
# # 数据清洗

# %%
# 数据清洗：处理缺失数据
# 非数值特征编码
# 特征工程

#Ticket
#Age 使用每一个Pclass中的年龄的中位数填充年龄的缺失值
age_median_map = data_all[['Age', 'Pclass']].dropna().groupby('Pclass').agg({'Age' : 'median'}).to_dict()
data_all.Age = data_all.Age.fillna(data_all.Pclass.map(age_median_map['Age']))

# %%
#Fare票价使用价格的平均数填充(这里能否也按照Pclass分组呢？)
data_all.Fare = data_all.Fare.fillna(data_all.Fare.dropna().mean())

# %%
#Embarked 港口空值用X填充
data_all.Embarked = data_all.Embarked.fillna('X')

# %%
#船舱号的空值用X填充，并且取所有舱号的首字符作为舱号
data_all.Cabin = data_all.Cabin.fillna('X').map(lambda x : x[0].strip())

# %%
data_all.Ticket = data_all.Ticket.fillna('X').map(lambda x:str(x).split()[0] if len(str(x).split()) > 1 else 'X')

# %%
data_all.Name = data_all.Name.map(lambda x : x.split(',')[0])

# %% [markdown]
# # 特征编码（特征工程）

# %%
#数值类型的特征不变，对于非数值类型的数据进行编码
numerical_cols = ['Survived', 'Age', 'SibSp', 'Parch', 'Fare', 'Pclass']
one_hot_encode_cols = ['Sex', 'Cabin', 'Embarked']
label_encode_cols = ['Name', 'Ticket']

# %%
from sklearn.preprocessing import LabelEncoder
def label_encode(df):
    le = LabelEncoder()
    return le.fit_transform(df)

# %%
#get_dummies只对于非数值型数据使用，对于数值型使用需要先转成str
#LabelEncoder的fit的参数的shape必须是一维的，例如(12,),所以这里使用apply而不能直接fit_transform(data_all[label_encode_cols])
numerical_df = data_all[numerical_cols]
one_hot_encode_df = pd.get_dummies(data_all[one_hot_encode_cols])
label_encode_df = data_all[label_encode_cols].apply(label_encode)

data_all = pd.concat([numerical_df, one_hot_encode_df, label_encode_df], axis=1)

# %%
data_all.shape
# Out:
# (200000, 23)

# %% [markdown]
# # LightGBM模型

# %%
#数据集划分
X_train = data_all[:train_data.shape[0]].drop(columns='Survived')
Y_train = data_all[:train_data.shape[0]]['Survived']
X_test = data_all[train_data.shape[0]:].drop(columns='Survived')

# %%
params = {
    'metric': 'binary_logloss',
    'n_estimators': 10000,
    'objective': 'binary',
    'random_state': 2021,
    'learning_rate': 0.02,
    'min_child_samples': 150,
    'reg_alpha': 3e-5,
    'reg_lambda': 9e-2,
    'num_leaves': 20,
    'max_depth': 16,
    'colsample_bytree': 0.8,
    'subsample': 0.8,
    'subsample_freq': 2,
    'max_bin': 240
}

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
import lightgbm as lgb
#StratifiedKFold会按照原始样本中的标签比例采样
skf = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)
pred = 0

#交叉验证
for fold, (train_idx, valid_idx) in enumerate(skf.split(X_train, Y_train)):
    print("======FOLD {}======".format(fold))
    #获取数据集
    x_train, y_train = X_train.iloc[train_idx], Y_train.iloc[train_idx]
    x_valid, y_valid = X_train.iloc[valid_idx], Y_train.iloc[valid_idx]
#     print(x_train.shape, y_train.shape)
    
    model = lgb.LGBMRegressor(**params)
    model.fit(
        x_train, y_train,
        eval_set=[(x_train, y_train), (x_valid, y_valid)],
        early_stopping_rounds=100,
        verbose=500
    )
    
    valid_pred = model.predict(x_valid)
    pred += model.predict(X_test, num_iteration=model.best_iteration_) / skf.n_splits
    acc_score = accuracy_score(y_valid, np.where(valid_pred>0.5, 1, 0))
    print("======Accuracy Score {}======".format(acc_score))
# Out:
# ======FOLD 0======
# Training until validation scores don't improve for 100 rounds
# [500]	training's binary_logloss: 0.460937	valid_1's binary_logloss: 0.476701
# Early stopping, best iteration is:
# [755]	training's binary_logloss: 0.457068	valid_1's binary_logloss: 0.476236
# ======Accuracy Score 0.7769223077692231======
# ======FOLD 1======
# Training until validation scores don't improve for 100 rounds
# [500]	training's binary_logloss: 0.461257	valid_1's binary_logloss: 0.473533
# Early stopping, best iteration is:
# [571]	training's binary_logloss: 0.460082	valid_1's binary_logloss: 0.473459
# ======Accuracy Score 0.7794220577942206======
# ======FOLD 2======
# Training until validation scores don't improve for 100 rounds
# [500]	training's binary_logloss: 0.46105	valid_1's binary_logloss: 0.475285
# Early stopping, best iteration is:
# [578]	training's binary_logloss: 0.459733	valid_1's binary_logloss: 0.475154
# ======Accuracy Score 0.7775222477752225======
# ...

# %%
lgb.plot_importance(model)

# %%
submission_path = './data/sample_submission.csv'
submission = pd.read_csv(submission_path)
submission.Survived = np.where(pred > 0.5, 1, 0)
submission.to_csv('submission.csv', index=False)

# %%
y_train.shape
# Out:
# (89999,)

# %%
Survived_0 = train_data.Embarked[train_data.Survived == 0].value_counts()
Survived_1 = train_data.Embarked[train_data.Survived == 1].value_counts()
Survived_1
# Out:
# S    22745
# C    16669
# Q     3238
# Name: Embarked, dtype: int64

# %%
train_data.shape
# Out:
# (100000, 12)

# %%
test_data.head()
# Out:
#    PassengerId  Pclass              Name     Sex   Age  SibSp  Parch  Ticket  \
# 0       100000       3  Holliday, Daniel    male  19.0      0      0   24745
# 1       100001       3  Nguyen, Lorraine  female  53.0      0      0   13264
# 2       100002       1   Harris, Heather  female  19.0      0      0   25990
# 3       100003       2      Larsen, Eric    male  25.0      0      0  314011
# 4       100004       1     Cleary, Sarah  female  17.0      0      2   26203
#
#     Fare   Cabin Embarked
# 0  63.01     NaN        S
# 1   5.81     NaN        S
# 2  38.91  B15315        C
# 3  12.93     NaN        S
# 4  26.89  B22515        C

# %%
data_all.Name.head()
# Out:
# 0    Oconnor
# 1      Bryan
# 2      Owens
# 3     Kramer
# 4       Bond
# Name: Name, dtype: object
